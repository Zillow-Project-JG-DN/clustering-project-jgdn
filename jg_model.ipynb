# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import env
import eval_model
import wrangle3


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')


pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option('display.float_format', lambda x: '%.5f' % x)



import gmaps
import gmaps.datasets

gmaps.configure(api_key="AIzaSyDlW6BYId6BmIp-mmA_lY_xNiQOKabd-2Q")


#Modeling Tools
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import statsmodels.api as sm
from statsmodels.formula.api import ols

from datetime import date
from scipy import stats


## Evaluation tools
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

# %%
train, X_train, y_train, X_validate, y_validate, X_test, y_test=wrangle3.wrangle()

# %%
X_train.head()
# Out:
#        Unnamed: 0  parcelid  bathroomcnt  bedroomcnt  \
# 21580       21580  11204960      3.00000     4.00000
# 32781       32781  14323862      6.00000     6.00000
# 33161       33161  12205584      2.00000     3.00000
# 45785       45785  12078527      3.00000     4.00000
# 45820       45820  14266520      3.00000     4.00000
#
#        calculatedfinishedsquarefeet       fips  latitude  longitude  \
# 21580                    2000.00000 6037.00000  34.56170 -118.08275
# 32781                    7393.00000 6059.00000  33.60152 -117.84523
# 33161                    1778.00000 6037.00000  33.96600 -118.29863
# 45785                    2777.00000 6037.00000  34.16601 -118.21853
# 45820                    1939.00000 6059.00000  33.70670 -117.89868
#
#        lotsizesquarefeet  regionidcity  regionidcounty  regionidzip  \
# 21580         6999.00000   40227.00000      3101.00000  97328.00000
# 32781        24000.00000   40009.00000      1286.00000  96975.00000
# 33161         4948.00000   12447.00000      3101.00000  96025.00000
# 45785         9989.00000   45457.00000      3101.00000  96327.00000
# 45820         6028.00000   47568.00000      1286.00000  97004.00000
#
#        yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 21580 1987.00000                104877.00000       131090.00000
# 32781 1995.00000               1556016.00000      2449943.00000
# 33161 1936.00000                 87000.00000       347000.00000
# 45785 1990.00000                322342.00000       875355.00000
# 45820 1971.00000                139321.00000       327623.00000
#
#        landtaxvaluedollarcnt   taxamount       county      age  age_bin  \
# 21580            26213.00000  2623.93000  Los_Angeles 30.00000  0.20000
# 32781           893927.00000 29921.84000       Orange 22.00000  0.20000
# 33161           260000.00000  4248.21000  Los_Angeles 81.00000  0.60000
# 45785           553013.00000  9603.39000  Los_Angeles 27.00000  0.20000
# 45820           188302.00000  3923.98000       Orange 46.00000  0.33300
#
#        taxrate   acres  acres_bin  sqft_bin  structure_dollar_per_sqft  \
# 21580  2.00162 0.16067    0.20000   0.40000                   52.43850
# 32781  1.22133 0.55096    0.40000   0.90000                  210.47153
# 33161  1.22427 0.11359    0.10000   0.40000                   48.93138
# 45785  1.09709 0.22932    0.20000   0.60000                  116.07562
# 45820  1.19771 0.13838    0.10000   0.40000                   71.85199
#
#        structure_dollar_sqft_bin  land_dollar_per_sqft  lot_dollar_sqft_bin  \
# 21580                    0.20000               3.74525              0.10000
# 32781                    0.60000              37.24696              0.30000
# 33161                    0.10000              52.54648              0.40000
# 45785                    0.40000              55.36220              0.40000
# 45820                    0.20000              31.23789              0.30000
#
#        bath_bed_ratio  cola  logerror_bins  baseline  scaled_latitude  \
# 21580         0.75000     0  (-0.05, 0.05]   0.01791          0.82963
# 32781         1.00000     0    (0.05, 0.2]   0.01791          0.17714
# 33161         0.66667     1  (-0.05, 0.05]   0.01791          0.42483
# 45785         0.75000     0    (0.05, 0.2]   0.01791          0.56074
# 45820         0.75000     0  (-0.05, 0.05]   0.01791          0.24862
#
#        scaled_longitude  scaled_bathroomcnt  scaled_taxrate  \
# 21580           0.73177             0.33333         0.20338
# 32781           0.85659             0.83333         0.12372
# 33161           0.61833             0.16667         0.12402
# 45785           0.66042             0.33333         0.11104
# 45820           0.82851             0.33333         0.12131
#
#        scaled_bedroomcnt  scaled_lotsizesquarefeet  scaled_age  scaled_acres  \
# 21580            0.50000                   0.00883     0.21324       0.00883
# 32781            0.83333                   0.03101     0.15441       0.03101
# 33161            0.33333                   0.00615     0.58824       0.00615
# 45785            0.50000                   0.01273     0.19118       0.01273
# 45820            0.50000                   0.00756     0.33088       0.00756
#
#        scaled_bath_bed_ratio  scaled_calculatedfinishedsquarefeet  \
# 21580                0.19643                              0.17285
# 32781                0.28571                              0.74125
# 33161                0.16667                              0.14945
# 45785                0.19643                              0.25474
# 45820                0.19643                              0.16642
#
#               area_cluster size_cluster price_cluster  area_cluster_la_newer  \
# 21580  palmdale_landcaster            f             c                      0
# 32781             se_coast            d             a                      0
# 33161             la_older            b             d                      0
# 45785        santa_clarita            f             a                      0
# 45820             se_coast            f             d                      0
#
#        area_cluster_la_older  area_cluster_northwest_costal  \
# 21580                      0                              0
# 32781                      0                              0
# 33161                      1                              0
# 45785                      0                              0
# 45820                      0                              0
#
#        area_cluster_palmdale_landcaster  area_cluster_santa_clarita  \
# 21580                                 1                           0
# 32781                                 0                           0
# 33161                                 0                           0
# 45785                                 0                           1
# 45820                                 0                           0
#
#        area_cluster_se_coast  size_cluster_a  size_cluster_b  size_cluster_c  \
# 21580                      0               0               0               0
# 32781                      1               0               0               0
# 33161                      0               0               1               0
# 45785                      0               0               0               0
# 45820                      1               0               0               0
#
#        size_cluster_d  size_cluster_e  size_cluster_f  size_cluster_g  \
# 21580               0               0               1               0
# 32781               1               0               0               0
# 33161               0               0               0               0
# 45785               0               0               1               0
# 45820               0               0               1               0
#
#        price_cluster_a  price_cluster_b  price_cluster_c  price_cluster_d  \
# 21580                0                0                1                0
# 32781                1                0                0                0
# 33161                0                0                0                1
# 45785                1                0                0                0
# 45820                0                0                0                1
#
#        price_cluster_e
# 21580                0
# 32781                0
# 33161                0
# 45785                0
# 45820                0

# %%
train2 = X_train

# %%
train2['log_error']=y_train

# %%
train2.sample(50)
# Out:
#        Unnamed: 0  parcelid  bathroomcnt  bedroomcnt  \
# 31805       31805  17059759      1.00000     3.00000
# 22592       22592  14455609      6.50000     6.00000
# 32642       32642  11975726      1.00000     2.00000
# 17516       17516  12683101      3.00000     4.00000
# 37603       37603  14455797      2.00000     3.00000
# 8815         8815  11934418      2.00000     3.00000
# 37010       37010  17074158      3.00000     4.00000
# 6278         6278  13068084      4.00000     5.00000
# 17872       17872  17072930      2.00000     3.00000
# 17099       17099  11638465      6.00000     6.00000
# 3706         3706  12925268      1.00000     3.00000
# 186           186  14391477      2.50000     4.00000
# 50784                    0.40000             103.37091              0.50000
# 48468                    0.10000               3.47014              0.10000
# 48141                    0.30000              21.10327              0.30000
# 37245                    0.00000               4.75170              0.10000
# 34428                    0.50000              47.60036              0.30000
# 42130                    0.10000              47.02169              0.30000
# 30993                    0.10000               5.71781              0.20000
# 17389                    0.20000               2.75677              0.10000
# 31750                    0.60000              10.63401              0.20000
# 13790                    0.50000               8.38852              0.20000
#
#        bath_bed_ratio  cola  logerror_bins  baseline  scaled_latitude  \
# 31805         0.33333     0  (-0.05, 0.05]   0.01791          0.72935
# 22592         1.08333     0  (-0.05, 0.05]   0.01791          0.09240
# 32642         0.50000     1  (-0.2, -0.05]   0.01791          0.53255
# 17516         0.75000     0  (-0.05, 0.05]   0.01791          0.31228
# 37603         0.66667     0  (-0.05, 0.05]   0.01791          0.13809
# 8815          0.66667     1  (-0.2, -0.05]   0.01791          0.49971
# 37010         0.75000     0  (-0.05, 0.05]   0.01791          0.64594
# 6278          0.80000     0    (0.05, 0.2]   0.01791          0.46614
# 17872         0.66667     0    (0.05, 0.2]   0.01791          0.64792
# 17099         1.00000     0  (-0.05, 0.05]   0.01791          0.49997
# 3706          0.33333     0  (-0.2, -0.05]   0.01791          0.51252
# 186           0.62500     0  (-0.05, 0.05]   0.01791          0.16639
# 31672         0.33333     0  (-0.05, 0.05]   0.01791          0.57934
# 16191         1.00000     0  (-0.05, 0.05]   0.01791          0.87717
# 50359         0.66667     0    (0.05, 0.2]   0.01791          0.72950
# 51401         0.66667     1  (-0.2, -0.05]   0.01791          0.63152
# 37888         1.00000     0   (-5.0, -0.2]   0.01791          0.55838
# 44461         0.50000     0    (0.05, 0.2]   0.01791          0.39746
# 36088         0.75000     0  (-0.05, 0.05]   0.01791          0.90953
# 47820         0.33333     0  (-0.2, -0.05]   0.01791          0.40255
# 48714         0.50000     1  (-0.05, 0.05]   0.01791          0.48269
# 21102         0.75000     0  (-0.05, 0.05]   0.01791          0.37559
# 52010         0.50000     0  (-0.05, 0.05]   0.01791          0.34720
# 40171         0.66667     0    (0.05, 0.2]   0.01791          0.48923
# 23632         0.50000     0   (-5.0, -0.2]   0.01791          0.71525
# 32845         0.66667     0  (-0.05, 0.05]   0.01791          0.36912
# 468           0.50000     1  (-0.2, -0.05]   0.01791          0.51111
# 3669          0.60000     1  (-0.05, 0.05]   0.01791          0.64749
# 45295         1.00000     0  (-0.05, 0.05]   0.01791          0.31715
# 29672         0.83333     0  (-0.05, 0.05]   0.01791          0.34938
# 8267          0.62500     0  (-0.05, 0.05]   0.01791          0.29002
# 16479         0.50000     0  (-0.05, 0.05]   0.01791          0.34336
# 28480         0.75000     0  (-0.05, 0.05]   0.01791          0.30273
# 50420         0.75000     0  (-0.05, 0.05]   0.01791          0.59658
# 1737          1.00000     1  (-0.05, 0.05]   0.01791          0.52785
# 18038         0.50000     0    (0.05, 0.2]   0.01791          0.29194
# 13492         0.50000     0  (-0.05, 0.05]   0.01791          0.42572
# 20607         0.75000     0   (-5.0, -0.2]   0.01791          0.41735
# 50359                0.16667                              0.07915
# 51401                0.16667                              0.07146
# 37888                0.28571                              0.51602
# 44461                0.10714                              0.03288
# 36088                0.19643                              0.22745
# 47820                0.04762                              0.07905
# 48714                0.10714                              0.15894
# 21102                0.19643                              0.21353
# 52010                0.10714                              0.05428
# 40171                0.16667                              0.13586
# 23632                0.10714                              0.07430
# 32845                0.16667                              0.11056
# 468                  0.10714                              0.07715
# 3669                 0.14286                              0.23640
# 45295                0.28571                              0.20067
# 29672                0.22619                              0.18139
# 8267                 0.15179                              0.18539
# 16479                0.10714                              0.10877
# 28480                0.19643                              0.31324
# 50420                0.19643                              0.23272
# 1737                 0.28571                              0.10919
# 18038                0.10714                              0.09412
# 13492                0.10714                              0.13565
# 20607                0.19643                              0.27097
# 51429                0.16667                              0.30175
# 3333                 0.28571                              0.20405
# 50784                0.16667                              0.17991
# 48468                0.16667                              0.08990
# 48141                0.16667                              0.14429
# 37245                0.10714                              0.09138
# 34428                0.04762                              0.04595
# 42130                0.16667                              0.13143
# 30993                0.28571                              0.11151
# 17389                0.19643                              0.18539
# 31750                0.25000                              0.49304
# 13790                0.16667                              0.15683
#
#               area_cluster size_cluster price_cluster  area_cluster_la_newer  \
# 31805     northwest_costal            g             d                      0
# 22592             se_coast            d             a                      0
# 32642             la_older            g             a                      0
# 17516             la_newer            f             a                      1
# 37603             se_coast            b             d                      0
# 8815              la_older            b             a                      0
# 37010     northwest_costal            f             a                      0
# 6278              la_newer            d             d                      1
# 17872     northwest_costal            b             a                      0
# 17099             la_older            d             a                      0
# 3706              la_newer            g             d                      1
# 186               se_coast            f             a                      0
# 31672        santa_clarita            g             a                      0
# 16191  palmdale_landcaster            a             d                      0
# 50359        santa_clarita            b             d                      0
# 51401        santa_clarita            b             a                      0
# 37888        santa_clarita            d             a                      0
# 44461             la_older            g             a                      0
# 36088  palmdale_landcaster            f             d                      0
# 47820             la_older            g             d                      0
# 48714        santa_clarita            c             a                      0
# 21102             la_older            f             d                      0
# 52010             la_newer            g             c                      1
# 40171             la_newer            b             a                      1
# 23632     northwest_costal            g             a                      0
# 32845             la_newer            b             a                      1
# 468               la_older            g             d                      0
# 3669         santa_clarita            f             d                      0
# 45295             la_newer            d             a                      1
# 29672             la_newer            f             d                      1
# 8267              la_newer            f             d                      1
# 16479             la_older            g             d                      0
# 28480             se_coast            f             a                      0
# 50420     northwest_costal            f             a                      0
# 1737         santa_clarita            a             d                      0
# 18038             la_newer            g             a                      1
# 13492             la_newer            c             a                      1
# 20607             la_newer            f             d                      1
# 51429             se_coast            f             a                      0
# 3333         santa_clarita            d             d                      0
# 50784        santa_clarita            f             a                      0
# 48468             la_newer            b             c                      1
# 48141        santa_clarita            b             d                      0
# 37245             la_older            g             d                      0
# 34428             la_older            g             a                      0
# 42130             la_newer            b             d                      1
# 30993        santa_clarita            a             d                      0
# 17389        santa_clarita            f             d                      0
# 31750             se_coast            d             a                      0
# 13790     northwest_costal            b             a                      0
#
#        area_cluster_la_older  area_cluster_northwest_costal  \
# 31805                      0                              1
# 1737                 0                0                0                1
# 18038                1                0                0                0
# 13492                1                0                0                0
# 20607                0                0                0                1
# 51429                1                0                0                0
# 3333                 0                0                0                1
# 50784                1                0                0                0
# 48468                0                0                1                0
# 48141                0                0                0                1
# 37245                0                0                0                1
# 34428                1                0                0                0
# 42130                0                0                0                1
# 30993                0                0                0                1
# 17389                0                0                0                1
# 31750                1                0                0                0
# 13790                1                0                0                0
#
#        price_cluster_e  log_error
# 31805                0   -0.00747
# 22592                0   -0.01184
# 32642                0   -0.15684
# 17516                0    0.00178
# 37603                0   -0.04978
# 8815                 0   -0.05818
# 37010                0    0.04136
# 6278                 0    0.06945
# 17872                0    0.06175
# 17099                0   -0.04798
# 3706                 0   -0.05058
# 186                  0    0.00892
# 31672                0    0.00242
# 16191                0   -0.01017
# 50359                0    0.05749
# 51401                0   -0.05248
# 37888                0   -1.70234
# 44461                0    0.06371
# 36088                0   -0.02669
# 47820                0   -0.06997
# 48714                0    0.04803
# 21102                0    0.03041
# 52010                0    0.02557
# 40171                0    0.07948
# 23632                0   -0.24653
# 32845                0    0.02629
# 468                  0   -0.18576
# 3669                 0   -0.00620
# 45295                0    0.00460
# 29672                0    0.00707
# 8267                 0    0.00391
# 16479                0   -0.02925
# 28480                0    0.02846
# 50420                0   -0.01143
# 1737                 0   -0.02873
# 18038                0    0.16293
# 13492                0   -0.00914
# 20607                0   -0.26951
# 51429                0    0.03952
# 3333                 0    0.09975
# 50784                0    0.04044
# 48468                0   -0.00389
# 48141                0    0.05046
# 37245                0    0.03779
# 34428                0   -0.07625
# 42130                0   -0.00354
# 30993                0    0.05968
# 17389                0   -0.08368
# 31750                0   -0.02788
# 13790                0   -0.01051

# %%
train=train2

# %% [markdown]
# ## Make ols model with clusters as features

# %%
train.dtypes
# Out:
# Unnamed: 0                                int64
# parcelid                                  int64
# bathroomcnt                             float64
# bedroomcnt                              float64
# calculatedfinishedsquarefeet            float64
# fips                                    float64
# latitude                                float64
# longitude                               float64
# lotsizesquarefeet                       float64
# regionidcity                            float64
# regionidcounty                          float64
# regionidzip                             float64
# yearbuilt                               float64
# structuretaxvaluedollarcnt              float64
# taxvaluedollarcnt                       float64
# landtaxvaluedollarcnt                   float64
# taxamount                               float64
# county                                   object
# age                                     float64
# age_bin                                 float64
# taxrate                                 float64
# acres                                   float64
# acres_bin                               float64
# sqft_bin                                float64
# structure_dollar_per_sqft               float64
# structure_dollar_sqft_bin               float64
# land_dollar_per_sqft                    float64
# lot_dollar_sqft_bin                     float64
# bath_bed_ratio                          float64
# cola                                      int64
# logerror_bins                          category
# baseline                                float64
# scaled_latitude                         float64
# scaled_longitude                        float64
# scaled_bathroomcnt                      float64
# scaled_taxrate                          float64
# scaled_bedroomcnt                       float64
# scaled_lotsizesquarefeet                float64
# scaled_age                              float64
# scaled_acres                            float64
# scaled_bath_bed_ratio                   float64
# scaled_calculatedfinishedsquarefeet     float64
# area_cluster                             object
# size_cluster                             object
# price_cluster                            object
# area_cluster_la_newer                     uint8
# area_cluster_la_older                     uint8
# area_cluster_northwest_costal             uint8
# area_cluster_palmdale_landcaster          uint8
# area_cluster_santa_clarita                uint8
# area_cluster_se_coast                     uint8
# size_cluster_a                            uint8
# size_cluster_b                            uint8
# size_cluster_c                            uint8
# size_cluster_d                            uint8
# size_cluster_e                            uint8
# size_cluster_f                            uint8
# size_cluster_g                            uint8
# price_cluster_a                           uint8
# price_cluster_b                           uint8
# price_cluster_c                           uint8
# price_cluster_d                           uint8
# price_cluster_e                           uint8
# log_error                               float64
# dtype: object

# %%
train.head()
# Out:
#        Unnamed: 0  parcelid  bathroomcnt  bedroomcnt  \
# 21580       21580  11204960      3.00000     4.00000
# 32781       32781  14323862      6.00000     6.00000
# 33161       33161  12205584      2.00000     3.00000
# 45785       45785  12078527      3.00000     4.00000
# 45820       45820  14266520      3.00000     4.00000
#
#        calculatedfinishedsquarefeet       fips  latitude  longitude  \
# 21580                    2000.00000 6037.00000  34.56170 -118.08275
# 32781                    7393.00000 6059.00000  33.60152 -117.84523
# 33161                    1778.00000 6037.00000  33.96600 -118.29863
# 45785                    2777.00000 6037.00000  34.16601 -118.21853
# 45820                    1939.00000 6059.00000  33.70670 -117.89868
#
#        lotsizesquarefeet  regionidcity  regionidcounty  regionidzip  \
# 21580         6999.00000   40227.00000      3101.00000  97328.00000
# 32781        24000.00000   40009.00000      1286.00000  96975.00000
# 33161         4948.00000   12447.00000      3101.00000  96025.00000
# 45785         9989.00000   45457.00000      3101.00000  96327.00000
# 45820         6028.00000   47568.00000      1286.00000  97004.00000
#
#        yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 21580 1987.00000                104877.00000       131090.00000
# 32781 1995.00000               1556016.00000      2449943.00000
# 33161 1936.00000                 87000.00000       347000.00000
# 45785 1990.00000                322342.00000       875355.00000
# 45820 1971.00000                139321.00000       327623.00000
#
#        landtaxvaluedollarcnt   taxamount       county      age  age_bin  \
# 21580            26213.00000  2623.93000  Los_Angeles 30.00000  0.20000
# 32781           893927.00000 29921.84000       Orange 22.00000  0.20000
# 33161           260000.00000  4248.21000  Los_Angeles 81.00000  0.60000
# 45785           553013.00000  9603.39000  Los_Angeles 27.00000  0.20000
# 45820           188302.00000  3923.98000       Orange 46.00000  0.33300
#
#        taxrate   acres  acres_bin  sqft_bin  structure_dollar_per_sqft  \
# 21580  2.00162 0.16067    0.20000   0.40000                   52.43850
# 32781  1.22133 0.55096    0.40000   0.90000                  210.47153
# 33161  1.22427 0.11359    0.10000   0.40000                   48.93138
# 45785  1.09709 0.22932    0.20000   0.60000                  116.07562
# 45820  1.19771 0.13838    0.10000   0.40000                   71.85199
#
#        structure_dollar_sqft_bin  land_dollar_per_sqft  lot_dollar_sqft_bin  \
# 21580                    0.20000               3.74525              0.10000
# 32781                    0.60000              37.24696              0.30000
# 33161                    0.10000              52.54648              0.40000
# 45785                    0.40000              55.36220              0.40000
# 45820                    0.20000              31.23789              0.30000
#
#        bath_bed_ratio  cola  logerror_bins  baseline  scaled_latitude  \
# 21580         0.75000     0  (-0.05, 0.05]   0.01791          0.82963
# 32781         1.00000     0    (0.05, 0.2]   0.01791          0.17714
# 33161         0.66667     1  (-0.05, 0.05]   0.01791          0.42483
# 45785         0.75000     0    (0.05, 0.2]   0.01791          0.56074
# 45820         0.75000     0  (-0.05, 0.05]   0.01791          0.24862
#
#        scaled_longitude  scaled_bathroomcnt  scaled_taxrate  \
# 21580           0.73177             0.33333         0.20338
# 32781           0.85659             0.83333         0.12372
# 33161           0.61833             0.16667         0.12402
# 45785           0.66042             0.33333         0.11104
# 45820           0.82851             0.33333         0.12131
#
#        scaled_bedroomcnt  scaled_lotsizesquarefeet  scaled_age  scaled_acres  \
# 21580            0.50000                   0.00883     0.21324       0.00883
# 32781            0.83333                   0.03101     0.15441       0.03101
# 33161            0.33333                   0.00615     0.58824       0.00615
# 45785            0.50000                   0.01273     0.19118       0.01273
# 45820            0.50000                   0.00756     0.33088       0.00756
#
#        scaled_bath_bed_ratio  scaled_calculatedfinishedsquarefeet  \
# 21580                0.19643                              0.17285
# 32781                0.28571                              0.74125
# 33161                0.16667                              0.14945
# 45785                0.19643                              0.25474
# 45820                0.19643                              0.16642
#
#               area_cluster size_cluster price_cluster  area_cluster_la_newer  \
# 21580  palmdale_landcaster            f             c                      0
# 32781             se_coast            d             a                      0
# 33161             la_older            b             d                      0
# 45785        santa_clarita            f             a                      0
# 45820             se_coast            f             d                      0
#
#        area_cluster_la_older  area_cluster_northwest_costal  \
# 21580                      0                              0
# 32781                      0                              0
# 33161                      1                              0
# 45785                      0                              0
# 45820                      0                              0
#
#        area_cluster_palmdale_landcaster  area_cluster_santa_clarita  \
# 21580                                 1                           0
# 32781                                 0                           0
# 33161                                 0                           0
# 45785                                 0                           1
# 45820                                 0                           0
#
#        area_cluster_se_coast  size_cluster_a  size_cluster_b  size_cluster_c  \
# 21580                      0               0               0               0
# 32781                      1               0               0               0
# 33161                      0               0               1               0
# 45785                      0               0               0               0
# 45820                      1               0               0               0
#
#        size_cluster_d  size_cluster_e  size_cluster_f  size_cluster_g  \
# 21580               0               0               1               0
# 32781               1               0               0               0
# 33161               0               0               0               0
# 45785               0               0               1               0
# 45820               0               0               1               0
#
#        price_cluster_a  price_cluster_b  price_cluster_c  price_cluster_d  \
# 21580                0                0                1                0
# 32781                1                0                0                0
# 33161                0                0                0                1
# 45785                1                0                0                0
# 45820                0                0                0                1
#
#        price_cluster_e  log_error
# 21580                0   -0.01503
# 32781                0    0.15846
# 33161                0   -0.01774
# 45785                0    0.06685
# 45820                0   -0.02213

# %%
# Create Model
ols_model1 = ols(formula='log_error ~ area_cluster_la_newer + area_cluster_la_older + area_cluster_northwest_costal + area_cluster_palmdale_landcaster + area_cluster_santa_clarita + area_cluster_se_coast + size_cluster_a + size_cluster_b + size_cluster_c + size_cluster_d + size_cluster_e + size_cluster_f + size_cluster_g + price_cluster_a + price_cluster_b + price_cluster_c + price_cluster_d + price_cluster_e', data=train).fit()

# Make predictions
ols_yhat = ols_model1.predict(X_train)
X_train['mvp_prdictions']=ols_yhat

#  DataFrame for evaluating model 
ols_eval = y_train.copy()
validate_eval = y_validate.copy()
ols_eval = pd.DataFrame(ols_eval)
validate_eval = pd.DataFrame(validate_eval)
ols_eval.rename(columns={'logerror': 'actual'}, inplace=True)
validate_eval.rename(columns={'logerror': 'actual'}, inplace=True)
validate_eval['ols_yhat'] = ols_model1.predict(X_validate)


# Add baseline - median home value
ols_eval['baseline_yhat'] = ols_eval['actual'].mean()
validate_eval['baseline_yhat'] = ols_eval['actual'].mean()
validate_eval['ols_yhat'] = ols_model1.predict(X_validate)

#  Compute the RMSE  and R2 for  ols model and baseline 
baseline_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.baseline_yhat)))
ols_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols_yhat)))

pct_change=round(((ols_RMSE-baseline_RMSE)/baseline_RMSE)*100, 2)
rmse_validate = (sqrt(mean_squared_error(validate_eval.actual, validate_eval.ols_yhat)))
baseline_r2 = (r2_score(ols_eval.actual, ols_eval.baseline_yhat))
ols_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols_yhat))
ols_validate_r2 = (r2_score(validate_eval.actual, validate_eval.ols_yhat))

#Output Findings

print(f'My model has value: {ols_RMSE < baseline_RMSE}')
print()
print(f'Baseline RMSE: {baseline_RMSE}')
print(f'My model train RMSE: {ols_RMSE}')
print(f'My model validate RMSE: {rmse_validate}')
print(f'RMSE difference baseline to model train: {baseline_RMSE- ols_RMSE}')
print(f'RMSE difference baseline to model validate: {baseline_RMSE- rmse_validate}')
print(f'RMSE difference train to validate: {ols_RMSE- rmse_validate}')
print(f'RMSE improvement: {pct_change}%')
print()
print(f'Baseline R2: {baseline_r2}')
print(f'Model train  R2: {ols_train_r2}')
print(f'Model Validate R2: {ols_validate_r2}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9y/17ptyrds267724n2_7s7hx340000gn/T/ipykernel_65739/1471296641.py in <module>
#      23 #  Compute the RMSE  and R2 for  ols model and baseline
#      24 baseline_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.baseline_yhat)))
# ---> 25 ols_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols_yhat)))
#      26
#      27 pct_change=round(((ols_RMSE-baseline_RMSE)/baseline_RMSE)*100, 2)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ols_yhat'

# %%
# Add baseline - median home value
ols_eval['baseline_yhat'] = ols_eval['actual'].mean()
validate_eval['baseline_yhat'] = ols_eval['actual'].mean()

# %%
ols_eval
# Out:
#         actual
# 21580 -0.01503
# 32781  0.15846
# 33161 -0.01774
# 45785  0.06685
# 45820 -0.02213
# ...        ...
# 14404  0.03122
# 1276   0.09111
# 34315 -0.01855
# 24599  0.18463
# 14306 -0.02481
#
# [36384 rows x 1 columns]

# %%
ols_eval
# Out:
#         actual  baseline_yhat
# 21580 -0.01503        0.01791
# 32781  0.15846        0.01791
# 33161 -0.01774        0.01791
# 45785  0.06685        0.01791
# 45820 -0.02213        0.01791
# ...        ...            ...
# 14404  0.03122        0.01791
# 1276   0.09111        0.01791
# 34315 -0.01855        0.01791
# 24599  0.18463        0.01791
# 14306 -0.02481        0.01791
#
# [36384 rows x 2 columns]

# %%
# Add model prediction
ols_eval['ols_yhat'] = ols_model1.predict(X_train)

# %%
ols_eval.head()
# Out:
#         actual  baseline_yhat  ols_yhat
# 21580 -0.01503        0.01791   0.01352
# 32781  0.15846        0.01791   0.03573
# 33161 -0.01774        0.01791   0.01181
# 45785  0.06685        0.01791   0.01187
# 45820 -0.02213        0.01791   0.04110

# %%
ols_eval
# Out:
#         actual  baseline_yhat  ols_yhat
# 21580 -0.01503        0.01791   0.01352
# 32781  0.15846        0.01791   0.03573
# 33161 -0.01774        0.01791   0.01181
# 45785  0.06685        0.01791   0.01187
# 45820 -0.02213        0.01791   0.04110
# ...        ...            ...       ...
# 14404  0.03122        0.01791   0.04110
# 1276   0.09111        0.01791   0.01591
# 34315 -0.01855        0.01791   0.01097
# 24599  0.18463        0.01791   0.02338
# 14306 -0.02481        0.01791   0.01507
#
# [36384 rows x 3 columns]

# %% [markdown]
# -[] Wranlge need to add clusters and encoding to x_validate

# %%
X_validate.head()
# Out:
#        Unnamed: 0  parcelid  bathroomcnt  bedroomcnt  \
# 20430       20430  11304460      3.00000     4.00000
# 36350       36350  14260987      2.00000     4.00000
# 24457       24457  14066920      2.50000     4.00000
# 47718       47718  11236044      2.00000     3.00000
# 46236       46236  11317435      3.00000     4.00000
#
#        calculatedfinishedsquarefeet       fips  latitude  longitude  \
# 20430                    2334.00000 6037.00000  34.68774 -118.18418
# 36350                    1361.00000 6059.00000  33.72950 -117.90591
# 24457                    1840.00000 6059.00000  33.71017 -118.02330
# 47718                    1244.00000 6037.00000  34.54453 -118.07068
# 46236                    2200.00000 6037.00000  34.68003 -118.24310
#
#        lotsizesquarefeet  regionidcity  regionidcounty  regionidzip  \
# 20430         6631.00000    5534.00000      3101.00000  97319.00000
# 36350         7800.00000   47568.00000      1286.00000  97004.00000
# 24457         6305.00000   25218.00000      1286.00000  96967.00000
# 47718         7040.00000   40227.00000      3101.00000  97328.00000
# 46236         7759.00000    5534.00000      3101.00000  97319.00000
#
#        yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 20430 1990.00000                173161.00000       216450.00000
# 36350 1960.00000                 62078.00000       382037.00000
# 24457 1965.00000                126210.00000       711616.00000
# 47718 1993.00000                114200.00000       199000.00000
# 46236 2005.00000                204300.00000       273000.00000
#
#        landtaxvaluedollarcnt  taxamount       county      age  age_bin  \
# 20430            43289.00000 3463.67000  Los_Angeles 27.00000  0.20000
# 36350           319959.00000 4531.62000       Orange 57.00000  0.40000
# 24457           585406.00000 7920.96000       Orange 52.00000  0.40000
# 47718            84800.00000 3453.14000  Los_Angeles 24.00000  0.20000
# 46236            68700.00000 4280.00000  Los_Angeles 12.00000  0.13300
#
#        taxrate   acres  acres_bin  sqft_bin  structure_dollar_per_sqft  \
# 20430  1.60022 0.15223    0.20000   0.50000                   74.19066
# 36350  1.18617 0.17906    0.20000   0.30000                   45.61205
# 24457  1.11309 0.14474    0.10000   0.40000                   68.59239
# 47718  1.73525 0.16162    0.20000   0.20000                   91.80064
# 46236  1.56777 0.17812    0.20000   0.50000                   92.86364
#
#        structure_dollar_sqft_bin  land_dollar_per_sqft  lot_dollar_sqft_bin  \
# 20430                    0.20000               6.52828              0.20000
# 36350                    0.10000              41.02038              0.30000
# 24457                    0.20000              92.84790              0.40000
# 47718                    0.30000              12.04545              0.20000
# 46236                    0.30000               8.85423              0.20000
#
#        bath_bed_ratio  cola  baseline  scaled_latitude  scaled_longitude  \
# 20430         0.75000     0   0.01791          0.91529           0.67847
# 36350         0.50000     0   0.01791          0.26411           0.82471
# 24457         0.62500     0   0.01791          0.25097           0.76302
# 47718         0.66667     0   0.01791          0.81797           0.73812
# 46236         0.75000     0   0.01791          0.91005           0.64751
#
#        scaled_bathroomcnt  scaled_taxrate  scaled_bedroomcnt  \
# 20430             0.33333         0.16240            0.50000
# 36350             0.16667         0.12013            0.50000
# 24457             0.25000         0.11267            0.50000
# 47718             0.16667         0.17619            0.33333
# 46236             0.33333         0.15909            0.50000
#
#        scaled_lotsizesquarefeet  scaled_age  scaled_acres  \
# 20430                   0.00834     0.19118       0.00834
# 36350                   0.00987     0.41176       0.00987
# 24457                   0.00792     0.37500       0.00792
# 47718                   0.00888     0.16912       0.00888
# 46236                   0.00982     0.08088       0.00982
#
#        scaled_bath_bed_ratio  scaled_calculatedfinishedsquarefeet  \
# 20430                0.19643                              0.20805
# 36350                0.10714                              0.10550
# 24457                0.15179                              0.15599
# 47718                0.16667                              0.09317
# 46236                0.19643                              0.19393
#
#               area_cluster size_cluster price_cluster  area_cluster_la_newer  \
# 20430  palmdale_landcaster            f             c                      0
# 36350             la_newer            c             d                      1
# 24457             la_newer            b             a                      1
# 47718  palmdale_landcaster            b             c                      0
# 46236  palmdale_landcaster            f             c                      0
#
#        area_cluster_la_older  area_cluster_northwest_costal  \
# 20430                      0                              0
# 36350                      0                              0
# 24457                      0                              0
# 47718                      0                              0
# 46236                      0                              0
#
#        area_cluster_palmdale_landcaster  area_cluster_santa_clarita  \
# 20430                                 1                           0
# 36350                                 0                           0
# 24457                                 0                           0
# 47718                                 1                           0
# 46236                                 1                           0
#
#        area_cluster_se_coast  size_cluster_a  size_cluster_b  size_cluster_c  \
# 20430                      0               0               0               0
# 36350                      0               0               0               1
# 24457                      0               0               1               0
# 47718                      0               0               1               0
# 46236                      0               0               0               0
#
#        size_cluster_d  size_cluster_e  size_cluster_f  size_cluster_g  \
# 20430               0               0               1               0
# 36350               0               0               0               0
# 24457               0               0               0               0
# 47718               0               0               0               0
# 46236               0               0               1               0
#
#        price_cluster_a  price_cluster_b  price_cluster_c  price_cluster_d  \
# 20430                0                0                1                0
# 36350                0                0                0                1
# 24457                1                0                0                0
# 47718                0                0                1                0
# 46236                0                0                1                0
#
#        price_cluster_e
# 20430                0
# 36350                0
# 24457                0
# 47718                0
# 46236                0

# %%
validate_eval['ols_yhat'] = ols_model1.predict(X_validate)

# %% [markdown]
# Calculate Baseline RMSE

# %%
# Calculate and Add Residuals Column for Plotting
ols_eval['residuals'] = ols_eval.ols_yhat - ols_eval.actual
validate_eval['residuals'] = validate_eval.ols_yhat - validate_eval.actual

# %%
#  Compute the RMSE  and R2 for  ols model and baseline 
baseline_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.baseline_yhat)))
ols_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols_yhat)))

# %%
baseline_RMSE
# Out:
# 0.1747252013031296

# %%
ols_eval
# Out:
#         actual  baseline_yhat  ols_yhat  residuals  ols3_yhat  ols2_yhat  \
# 21580 -0.01503        0.01791   0.01352    0.02856    0.01204    0.01403
# 32781  0.15846        0.01791   0.03573   -0.12272    0.04401    0.06059
# 33161 -0.01774        0.01791   0.01181    0.02954    0.00578    0.00696
# 45785  0.06685        0.01791   0.01187   -0.05497    0.01263    0.01460
# 45820 -0.02213        0.01791   0.04110    0.06324    0.03121    0.03095
# ...        ...            ...       ...        ...        ...        ...
# 14404  0.03122        0.01791   0.04110    0.00988    0.03266    0.03305
# 1276   0.09111        0.01791   0.01591   -0.07520    0.00591    0.00759
# 34315 -0.01855        0.01791   0.01097    0.02952    0.01591    0.01746
# 24599  0.18463        0.01791   0.02338   -0.16125    0.02451    0.01804
# 14306 -0.02481        0.01791   0.01507    0.03988    0.02455    0.02659
#
#        ols4_yhat
# 21580    0.02238
# 32781    0.01968
# 33161    0.01250
# 45785    0.01900
# 45820    0.01852
# ...          ...
# 14404    0.01980
# 1276     0.01426
# 34315    0.01459
# 24599    0.01425
# 14306    0.01882
#
# [36384 rows x 7 columns]

# %%
baseline_RMSE
# Out:
# 0.1747252013031296

# %%
pct_change=round(((ols_RMSE-baseline_RMSE)/baseline_RMSE)*100, 2)
rmse_validate = (sqrt(mean_squared_error(validate_eval.actual, validate_eval.ols_yhat)))
baseline_r2 = (r2_score(ols_eval.actual, ols_eval.baseline_yhat))
ols_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols_yhat))
ols_validate_r2 = (r2_score(validate_eval.actual, validate_eval.ols_yhat))

#Output Findings

print(f'My model has value: {ols_RMSE < baseline_RMSE}')
print()
print(f'Baseline RMSE: {baseline_RMSE}')
print(f'My model train RMSE: {ols_RMSE}')
print(f'My model validate RMSE: {rmse_validate}')
print(f'RMSE difference baseline to model train: {baseline_RMSE- ols_RMSE}')
print(f'RMSE difference baseline to model validate: {baseline_RMSE- rmse_validate}')
print(f'RMSE difference train to validate: {ols_RMSE- rmse_validate}')
print(f'RMSE improvement: {pct_change}%')
print()
print(f'Baseline R2: {baseline_r2}')
print(f'Model train  R2: {ols_train_r2}')
print(f'Model Validate R2: {ols_validate_r2}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9y/17ptyrds267724n2_7s7hx340000gn/T/ipykernel_65739/3277745317.py in <module>
#       2 rmse_validate = (sqrt(mean_squared_error(validate_eval.actual, validate_eval.ols_yhat)))
#       3 baseline_r2 = (r2_score(ols_eval.actual, ols_eval.baseline_yhat))
# ----> 4 ols_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols_yhat))
#       5 ols_validate_r2 = (r2_score(validate_eval.actual, validate_eval.ols_yhat))
#       6
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ols_yhat'

# %%
train.dtypes
# Out:
# Unnamed: 0                                int64
# parcelid                                  int64
# bathroomcnt                             float64
# bedroomcnt                              float64
# calculatedfinishedsquarefeet            float64
# fips                                    float64
# latitude                                float64
# longitude                               float64
# lotsizesquarefeet                       float64
# regionidcity                            float64
# regionidcounty                          float64
# regionidzip                             float64
# yearbuilt                               float64
# structuretaxvaluedollarcnt              float64
# taxvaluedollarcnt                       float64
# landtaxvaluedollarcnt                   float64
# taxamount                               float64
# county                                   object
# age                                     float64
# age_bin                                 float64
# taxrate                                 float64
# acres                                   float64
# acres_bin                               float64
# sqft_bin                                float64
# structure_dollar_per_sqft               float64
# structure_dollar_sqft_bin               float64
# land_dollar_per_sqft                    float64
# lot_dollar_sqft_bin                     float64
# bath_bed_ratio                          float64
# cola                                      int64
# logerror_bins                          category
# baseline                                float64
# scaled_latitude                         float64
# scaled_longitude                        float64
# scaled_bathroomcnt                      float64
# scaled_taxrate                          float64
# scaled_bedroomcnt                       float64
# scaled_lotsizesquarefeet                float64
# scaled_age                              float64
# scaled_acres                            float64
# scaled_bath_bed_ratio                   float64
# scaled_calculatedfinishedsquarefeet     float64
# area_cluster                             object
# size_cluster                             object
# price_cluster                            object
# area_cluster_la_newer                     uint8
# area_cluster_la_older                     uint8
# area_cluster_northwest_costal             uint8
# area_cluster_palmdale_landcaster          uint8
# area_cluster_santa_clarita                uint8
# area_cluster_se_coast                     uint8
# size_cluster_a                            uint8
# size_cluster_b                            uint8
# size_cluster_c                            uint8
# size_cluster_d                            uint8
# size_cluster_e                            uint8
# size_cluster_f                            uint8
# size_cluster_g                            uint8
# price_cluster_a                           uint8
# price_cluster_b                           uint8
# price_cluster_c                           uint8
# price_cluster_d                           uint8
# price_cluster_e                           uint8
# log_error                               float64
# mvp_prdictions                          float64
# ols3_prdictions                         float64
# dtype: object

# %%
# Create Model
ols_model3 = ols(formula='log_error ~ area_cluster_la_newer + area_cluster_la_older + area_cluster_northwest_costal + area_cluster_palmdale_landcaster + area_cluster_santa_clarita + area_cluster_se_coast + taxvaluedollarcnt + structuretaxvaluedollarcnt + taxvaluedollarcnt + landtaxvaluedollarcnt + acres + age', data=train).fit()

# Make predictions
ols3_yhat = ols_model3.predict(X_train)
ols_eval['ols3_yhat']=ols3_yhat
X_train['ols3_prdictions']=ols3_yhat

# %%
ols_eval.head()
# Out:
#         actual  baseline_yhat  ols_yhat  residuals  ols3_yhat
# 21580 -0.01503        0.01791   0.01352    0.02856    0.01204
# 32781  0.15846        0.01791   0.03573   -0.12272    0.04401
# 33161 -0.01774        0.01791   0.01181    0.02954    0.00578
# 45785  0.06685        0.01791   0.01187   -0.05497    0.01263
# 45820 -0.02213        0.01791   0.04110    0.06324    0.03121

# %%
ols_eval.head()
# Out:
#         actual  baseline_yhat  ols_yhat  residuals  ols3_yhat
# 21580 -0.01503        0.01791   0.01352    0.02856    0.01204
# 32781  0.15846        0.01791   0.03573   -0.12272    0.04401
# 33161 -0.01774        0.01791   0.01181    0.02954    0.00578
# 45785  0.06685        0.01791   0.01187   -0.05497    0.01263
# 45820 -0.02213        0.01791   0.04110    0.06324    0.03121

# %%
ols_eval
# Out:
#         actual  baseline_yhat  ols_yhat  residuals  ols3_yhat
# 21580 -0.01503        0.01791   0.01352    0.02856    0.01204
# 32781  0.15846        0.01791   0.03573   -0.12272    0.04401
# 33161 -0.01774        0.01791   0.01181    0.02954    0.00578
# 45785  0.06685        0.01791   0.01187   -0.05497    0.01263
# 45820 -0.02213        0.01791   0.04110    0.06324    0.03121
# ...        ...            ...       ...        ...        ...
# 14404  0.03122        0.01791   0.04110    0.00988    0.03266
# 1276   0.09111        0.01791   0.01591   -0.07520    0.00591
# 34315 -0.01855        0.01791   0.01097    0.02952    0.01591
# 24599  0.18463        0.01791   0.02338   -0.16125    0.02451
# 14306 -0.02481        0.01791   0.01507    0.03988    0.02455
#
# [36384 rows x 5 columns]

# %%
#Calculate Evaluation metrics
baseline_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.baseline_yhat)))
ols_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols_yhat)))
ols3_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols3_yhat)))
pct_change_baseline=(((ols_RMSE-baseline_RMSE)/baseline_RMSE)*100)
pct_change_last_model=(((ols3_RMSE-ols_RMSE)/ols_RMSE)*100)
#rmse_validate = (sqrt(mean_squared_error(validate_eval.actual, validate_eval.ols2_yhat)))
baseline_r2 = (r2_score(ols_eval.actual, ols_eval.baseline_yhat))
ols3_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols3_yhat))
#ols2_validate_r2 = (r2_score(validate_eval.actual, validate_eval.ols2_yhat))
# Display findings
print(f'My model has value: {ols_RMSE < baseline_RMSE}')
print(f'My model beats previous model: {ols3_RMSE < ols_RMSE}')
print()
print(f'Baseline RMSE: {baseline_RMSE}')
print(f'Model 1 RMSE: {ols_RMSE}')
print(f'Current model train RMSE: {ols3_RMSE}')
#print(f'Currennt model validate RMSE: {rmse_validate}')
print()
print(f'Current model RMSE difference from baseline: {baseline_RMSE- ols_RMSE}')
#print(f'RMSE difference train to validate: {ols2_RMSE- rmse_validate}')
print(f'Current model baseline RMSE improvement: {pct_change_baseline}%')
#print(f'Current model RMSE improvement from last model: {pct_change_last_model}%')
print()
print(f'Baseline R2: {baseline_r2}')
print(f'Model train  R2: {ols3_train_r2}')
#print(f'Model Validate R2: {ols2_validate_r2}')
# Out:
# My model has value: True
# My model beats previous model: False
#
# Baseline RMSE: 0.1747252013031296
# Model 1 RMSE: 0.17434797056175116
# Current model train RMSE: 0.1745183892333338
#
# Current model RMSE difference from baseline: 0.00037723074137843704
# Current model baseline RMSE improvement: -0.21589944585268034%
#
# Baseline R2: 0.0
# Model train  R2: 0.0023658827981120067

# %%
train.dtypes
# Out:
# Unnamed: 0                                int64
# parcelid                                  int64
# bathroomcnt                             float64
# bedroomcnt                              float64
# calculatedfinishedsquarefeet            float64
# fips                                    float64
# latitude                                float64
# longitude                               float64
# lotsizesquarefeet                       float64
# regionidcity                            float64
# regionidcounty                          float64
# regionidzip                             float64
# yearbuilt                               float64
# structuretaxvaluedollarcnt              float64
# taxvaluedollarcnt                       float64
# landtaxvaluedollarcnt                   float64
# taxamount                               float64
# county                                   object
# age                                     float64
# age_bin                                 float64
# taxrate                                 float64
# acres                                   float64
# acres_bin                               float64
# sqft_bin                                float64
# structure_dollar_per_sqft               float64
# structure_dollar_sqft_bin               float64
# land_dollar_per_sqft                    float64
# lot_dollar_sqft_bin                     float64
# bath_bed_ratio                          float64
# cola                                      int64
# logerror_bins                          category
# baseline                                float64
# scaled_latitude                         float64
# scaled_longitude                        float64
# scaled_bathroomcnt                      float64
# scaled_taxrate                          float64
# scaled_bedroomcnt                       float64
# scaled_lotsizesquarefeet                float64
# scaled_age                              float64
# scaled_acres                            float64
# scaled_bath_bed_ratio                   float64
# scaled_calculatedfinishedsquarefeet     float64
# area_cluster                             object
# size_cluster                             object
# price_cluster                            object
# area_cluster_la_newer                     uint8
# area_cluster_la_older                     uint8
# area_cluster_northwest_costal             uint8
# area_cluster_palmdale_landcaster          uint8
# area_cluster_santa_clarita                uint8
# area_cluster_se_coast                     uint8
# size_cluster_a                            uint8
# size_cluster_b                            uint8
# size_cluster_c                            uint8
# size_cluster_d                            uint8
# size_cluster_e                            uint8
# size_cluster_f                            uint8
# size_cluster_g                            uint8
# price_cluster_a                           uint8
# price_cluster_b                           uint8
# price_cluster_c                           uint8
# price_cluster_d                           uint8
# price_cluster_e                           uint8
# log_error                               float64
# mvp_prdictions                          float64
# dtype: object

# %%
# Create Model
ols_model2 = ols(formula='log_error ~ area_cluster_la_newer + area_cluster_la_older + area_cluster_northwest_costal + area_cluster_palmdale_landcaster + area_cluster_santa_clarita + area_cluster_se_coast + bathroomcnt + bedroomcnt + calculatedfinishedsquarefeet + acres + age', data=train).fit()

# Make predictions
ols2_yhat = ols_model2.predict(X_train)
ols_eval['ols2_yhat']=ols2_yhat
X_train['ols2_prdictions']=ols2_yhat

# %%
#Calculate Evaluation metrics
baseline_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.baseline_yhat)))
ols_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols_yhat)))
ols2_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols2_yhat)))
pct_change_baseline=(((ols_RMSE-baseline_RMSE)/baseline_RMSE)*100)
pct_change_last_model=(((ols2_RMSE-ols_RMSE)/ols_RMSE)*100)
#rmse_validate = (sqrt(mean_squared_error(validate_eval.actual, validate_eval.ols2_yhat)))
baseline_r2 = (r2_score(ols_eval.actual, ols_eval.baseline_yhat))
ols2_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols2_yhat))
#ols2_validate_r2 = (r2_score(validate_eval.actual, validate_eval.ols2_yhat))
# Display findings
print(f'My model has value: {ols_RMSE < baseline_RMSE}')
print(f'My model beats previous model: {ols2_RMSE < ols_RMSE}')
print()
print(f'Baseline RMSE: {baseline_RMSE}')
print(f'Model 1 RMSE: {ols_RMSE}')
print(f'Current model train RMSE: {ols2_RMSE}')
#print(f'Current model validate RMSE: {rmse_validate}')
print()
print(f'Current model RMSE difference from baseline: {baseline_RMSE- ols_RMSE}')
#print(f'RMSE difference train to validate: {ols2_RMSE- rmse_validate}')
print(f'Current model baseline RMSE improvement: {pct_change_baseline}%')
print(f'Current model RMSE improvement from last model: {pct_change_last_model}%')
print()
print(f'Baseline R2: {baseline_r2}')
print(f'Model train  R2: {ols2_train_r2}')
#print(f'Model Validate R2: {ols2_validate_r2}')
# Out:
# My model has value: True
# My model beats previous model: False
#
# Baseline RMSE: 0.1747252013031296
# Model 1 RMSE: 0.17434797056175116
# Currennt model train RMSE: 0.17445037402983032
#
# Current model RMSE difference from baseline: 0.00037723074137843704
# Current model baseline RMSE improvement: -0.21589944585268034%
# Current model RMSE improvement from last model: 0.058735107583537983%
#
# Baseline R2: 0.0
# Model train  R2: 0.0031433488903251927

# %%
# Create Model
ols_model4 = ols(formula='log_error ~ taxvaluedollarcnt + structuretaxvaluedollarcnt + taxvaluedollarcnt + landtaxvaluedollarcnt + acres + age', data=train).fit()

# Make predictions
ols4_yhat = ols_model4.predict(X_train)
ols_eval['ols4_yhat']=ols4_yhat
X_train['ols4_prdictions']=ols4_yhat

# %%
#Calculate Evaluation metrics
baseline_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.baseline_yhat)))
ols_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols_yhat)))
ols2_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols2_yhat)))
ols3_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols3_yhat)))
ols4_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols4_yhat)))

pct_change_baseline=(((ols4_RMSE-baseline_RMSE)/baseline_RMSE)*100)
pct_change_last_model=(((ols4_RMSE-ols_RMSE)/ols_RMSE)*100)
#rmse_validate = (sqrt(mean_squared_error(validate_eval.actual, validate_eval.ols2_yhat)))
baseline_r2 = (r2_score(ols_eval.actual, ols_eval.baseline_yhat))
ols2_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols2_yhat))
ols3_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols3_yhat))
ols4_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols4_yhat))
#ols2_validate_r2 = (r2_score(validate_eval.actual, validate_eval.ols2_yhat))
# Display findings
print(f'My model has value: {ols_RMSE < baseline_RMSE}')
print(f'My model beats previous best model: {ols4_RMSE < ols_RMSE}')
print()
print(f'Baseline RMSE: {baseline_RMSE}')
print(f'Model 1 RMSE: {ols_RMSE}')
print(f'Current model train RMSE: {ols4_RMSE}')
#print(f'Current model validate RMSE: {rmse_validate}')
print()
print(f'Current model RMSE difference from baseline: {baseline_RMSE- ols4_RMSE}')
#print(f'RMSE difference train to validate: {ols2_RMSE- rmse_validate}')
print(f'Current model baseline RMSE improvement: {pct_change_baseline}%')
print(f'Current model RMSE improvement from last model: {pct_change_last_model}%')
print()
print(f'Baseline R2: {baseline_r2}')
print(f'Model train  R2: {ols4_train_r2}')
#print(f'Model Validate R2: {ols2_validate_r2}')
# Out:
# My model has value: True
# My model beats previous best model: False
#
# Baseline RMSE: 0.1747252013031296
# Model 1 RMSE: 0.17434797056175116
# Current model train RMSE: 0.17465868761475795
#
# Current model RMSE difference from baseline: 6.65136883716555e-05
# Current model baseline RMSE improvement: -0.03806759864952815%
# Current model RMSE improvement from last model: 0.17821661588927454%
#
# Baseline R2: 0.0
# Model train  R2: 0.0007612070587840192

# %%
baseline_r2
# Out:
# 0.0

# %%
# Create Model
ols_model5 = ols(formula='log_error ~ area_cluster_la_newer + area_cluster_la_older + area_cluster_northwest_costal + area_cluster_palmdale_landcaster + area_cluster_santa_clarita + area_cluster_se_coast + size_cluster_a + size_cluster_b + size_cluster_c + size_cluster_d + size_cluster_e + size_cluster_f + size_cluster_g + price_cluster_a + price_cluster_b + price_cluster_c + price_cluster_d + price_cluster_e + taxvaluedollarcnt + structuretaxvaluedollarcnt + taxvaluedollarcnt + landtaxvaluedollarcnt', data=train).fit()

# Make predictions
ols5_yhat = ols_model5.predict(X_train)
X_train['mvp_prdictions']=ols5_yhat
ols_eval['ols5_yhat']=ols5_yhat

ols5_validate_yhat = ols_model5.predict(X_validate)
X_validate['ols5_prdictions']=ols5_validate_yhat

# %%
ols_eval['ols5_yhat']=ols5_yhat

# %%
validate_eval.head()
# Out:
#         actual  ols_yhat  baseline_yhat
# 20430  0.02800   0.01352        0.01791
# 36350 -0.03456   0.03021        0.01791
# 24457 -0.00435   0.01097        0.01791
# 47718  0.01948   0.00652        0.01791
# 46236  0.04457   0.01352        0.01791

# %%
validate_eval['ols5_yhat']=ols5_validate_yhat

# %%
ols_eval.head()
# Out:
#         actual  baseline_yhat
# 21580 -0.01503        0.01791
# 32781  0.15846        0.01791
# 33161 -0.01774        0.01791
# 45785  0.06685        0.01791
# 45820 -0.02213        0.01791

# %%
ols_eval.head()
# Out:
#         actual  baseline_yhat  ols_yhat  ols5_yhat
# 21580 -0.01503        0.01791   0.01352    0.01352
# 32781  0.15846        0.01791   0.03573    0.03573
# 33161 -0.01774        0.01791   0.01181    0.01181
# 45785  0.06685        0.01791   0.01187    0.01187
# 45820 -0.02213        0.01791   0.04110    0.04110

# %%
validate_eval.head()
# Out:
#         actual  ols_yhat  baseline_yhat  ols5_yhat
# 20430  0.02800   0.01352        0.01791    0.01535
# 36350 -0.03456   0.03021        0.01791    0.02952
# 24457 -0.00435   0.01097        0.01791    0.00814
# 47718  0.01948   0.00652        0.01791    0.00532
# 46236  0.04457   0.01352        0.01791    0.01517

# %%
#Calculate Evaluation metrics
baseline_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.baseline_yhat)))
ols_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols_yhat)))
ols5_RMSE = (sqrt(mean_squared_error(ols_eval.actual, ols_eval.ols5_yhat)))
pct_change_baseline=(((ols5_RMSE-baseline_RMSE)/baseline_RMSE)*100)
pct_change_last_model=(((ols5_RMSE-ols_RMSE)/ols_RMSE)*100)
rmse_validate = (sqrt(mean_squared_error(validate_eval.actual, validate_eval.ols5_yhat)))
baseline_r2 = (r2_score(ols_eval.actual, ols_eval.baseline_yhat))
ols5_train_r2 = (r2_score(ols_eval.actual, ols_eval.ols5_yhat))
ols5_validate_r2 = (r2_score(validate_eval.actual, validate_eval.ols5_yhat))
# Display findings
print(f'My model has value: {ols_RMSE < baseline_RMSE}')
print(f'My model beats previous model: {ols5_RMSE < ols_RMSE}')
print()
print(f'Baseline RMSE: {baseline_RMSE}')
print(f'Model 1 RMSE: {ols_RMSE}')
print(f'Current model train RMSE: {ols5_RMSE}')
print(f'Current model validate RMSE: {rmse_validate}')
print()
print(f'Current model train RMSE difference from baseline: {baseline_RMSE- ols5_RMSE}')
print(f'Current model validate RMSE difference from baseline: {baseline_RMSE- rmse_validate}')
print()

print(f'Current model RMSE difference from best model: {ols5_RMSE- ols_RMSE}')
print()

print(f'RMSE difference train to validate: {ols2_RMSE- rmse_validate}')
print(f'Current model baseline RMSE improvement: {pct_change_baseline}%')
print(f'Current model RMSE improvement from last model: {pct_change_last_model}%')
print()
print(f'Baseline R2: {baseline_r2}')
print(f'Model train  R2: {ols3_train_r2}')
print(f'Model Validate R2: {ols5_validate_r2}')
# Out:
# My model has value: True
# My model beats previous model: True
#
# Baseline RMSE: 0.1747252013031296
# Model 1 RMSE: 0.17434797056175116
# Current model train RMSE: 0.1743396579027326
# Current model validate RMSE: 0.16987508165511148
#
# Current model train RMSE difference from baseline: 0.0003855434003970093
# Current model validate RMSE difference from baseline: 0.004850119648018125
#
# Current model RMSE difference from best model: -8.312659018572255e-06
#
# RMSE difference train to validate: 0.004575292374718848
# Current model baseline RMSE improvement: -0.22065700741596664%
# Current model RMSE improvement from last model: -0.004767855336536911%
#
# Baseline R2: 0.0
# Model train  R2: 0.0023658827981120067
# Model Validate R2: 0.00322978970601584
